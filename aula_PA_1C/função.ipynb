# %% [markdown]
# <a href="https://colab.research.google.com/github/henriqueabatista/PA_python/blob/main/aula_PA_1C/fun%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Funções

# %%
def saudacao(nome):
  print(f'{nome}, seja bem-vindo(a) ao curso de python!')

# %%
saudacao('Artur')
# Out:
# Artur, seja bem-vindo(a) ao curso de python!

# %%
from datetime import datetime

def mostrar_horario():
  agora= datetime.now()
  print(f'A hora atual é {agora.strftime ("%H:%M:%S")}')

# %%
mostrar_horario()
# Out:
# A hora atual é 14:04:19

# %%
def saudacaov1(nome, idade, curso):
  print(f'Olá {nome}, você tem {idade} anos, e participa do curso de {curso} ')

# %%
saudacaov1('Artur', 16, 'ADM')
# Out:
# Olá Artur, você tem 16 anos, e participa do curso de ADM

# %%
def verificar_paridade(numero):
  if numero %2 == 0:
    print(f'{numero} é par')

  else:
    print(f'{numero} é impar')

# %%
verificar_paridade(99)
# Out:
# 99 é impar

# %%
def mensagem():
  return 'hoje é um ótimo dia para programar!'

# %%
print(mensagem())
# Out:
# hoje é um ótimo dia para programar!

# %%
def somar(a, b):
  return a + b #soma de 2 numeros

def calcular_media(n1, n2):
  soma = somar(n1 ,n2)
  media = soma / 2
  return media

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))

resultado = calcular_media(nota1, nota2)
print(f'A média final é {resultado}')
# Out:
# Digite a primeira nota: 9
# Digite a segunda nota: 9
# A média final é 9.0

# %% [markdown]
# * Fazer uma função que calcula o preço total de um produto. A função receberá quantidade e preço unitario e retornara o total dos produtos

# %%
def somar(a, b):
  return a * b

def calcular_preço(quantidade, preço):
  return quantidade * preço
  soma = somar(quantidade * preço)
  produto = soma
  return soma

quantidade = int(input("Digite a quantidade: "))
preço = float(input("Digite o preço: "))

resultado = calcular_preço(quantidade, preço)
print(f'A preço total é {resultado}')
# Out:
# Digite a quantidade: 10
# Digite o preço: 2
# A preço total é 20.0
